# %% [markdown]
# # seaborn library Part 1

# %%
import pandas as pd

# %%
data1=pd.read_csv('Customer.csv')

# %%
data1.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 Customer ID    Customer Name    Segment  Age  \
# 0             0           0    CG-12520      Claire Gute   Consumer   67
# 1             1           1    DV-13045  Darrin Van Huff  Corporate   31
# 2             2           2    SO-20335   Sean O'Donnell   Consumer   65
# 3             3           3    BH-11710  Brosina Hoffman   Consumer   20
# 4             4           4    AA-10480     Andrew Allen   Consumer   50
#
#          Country             City           State  Postal Code Region  Salary
# 0  United States        Henderson        Kentucky        42420  South     100
# 1  United States      Los Angeles      California        90036   West     100
# 2  United States  Fort Lauderdale         Florida        33311  South     100
# 3  United States      Los Angeles      California        90032   West     100
# 4  United States          Concord  North Carolina        28027  South     100

# %%
import seaborn as sns

# %%
sns.distplot(data1.Age)
# Out:
# <ipython-input-40-c5308de39f4a>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data1.Age)
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# # Task 1

# %%
#Add 'salary' column
df=pd.read_csv("Customer.csv")

# %%
df['Salary']='100'

# %%
df.to_csv('Customer.csv')

# %%
df
# Out:
#      Unnamed: 0.1  Unnamed: 0 Customer ID      Customer Name      Segment  \
# 0               0           0    CG-12520        Claire Gute     Consumer
# 1               1           1    DV-13045    Darrin Van Huff    Corporate
# 2               2           2    SO-20335     Sean O'Donnell     Consumer
# 3               3           3    BH-11710    Brosina Hoffman     Consumer
# 4               4           4    AA-10480       Andrew Allen     Consumer
# ..            ...         ...         ...                ...          ...
# 788           788         788    CJ-11875       Carl Jackson    Corporate
# 789           789         789    RS-19870         Roy Skaria  Home Office
# 790           790         790    SC-20845         Sung Chung     Consumer
# 791           791         791    RE-19405    Ricardo Emerson     Consumer
# 792           792         792    SM-20905  Susan MacKendrick     Consumer
#
#      Age        Country               City           State  Postal Code  \
# ...

# %%
data2=pd.read_csv('Customer.csv')

# %%
sns.distplot(data2.Salary,kde=True,color='green')
# Out:
# <ipython-input-46-4c16bd211b0c>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data2.Salary,kde=True,color='green')
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py:2511: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# <Axes: xlabel='Salary', ylabel='Density'>

# %% [markdown]
# # seaborn library Part 2

# %%
iris=sns.load_dataset("iris")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
sns.jointplot(x="sepal_length",y="sepal_width",data=iris)

# %%
sns.pairplot(iris)

# %% [markdown]
# # Task 2

# %%
sns.jointplot(x="petal_length",y="petal_width",data=iris)
