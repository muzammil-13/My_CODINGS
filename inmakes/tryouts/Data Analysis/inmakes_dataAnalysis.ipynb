# %% [markdown]
# # Part 1

# %%
import pandas as pd

# %%
pd.read_csv("sales.csv")
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17    Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %%
sales=pd.read_csv("sales.csv")

# %%
sales.head(10)
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5   263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# 6    99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# 7   188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# 8   325637547  1/18/2018  15:33    Male    Park lane   Dallas    Yes
# 9   562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating
# 0  Groceries     30         1     30    Cash       2
# 1    Fashion     35         5    175    Card       3
# ...

# %%
sales.tail(10)
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 990   752407865  1/15/2018  10:01    Male  Water tower  Chicago    Yes
# 991   699906043  2/15/2018  12:58    Male   Brookfield  NewYork    Yes
# 992   927909627   3/2/2018  13:35    Male   Brookfield  NewYork     No
# 993   455112063  3/19/2018  17:30  Female   Brookfield  NewYork    Yes
# 994   446582560  1/31/2018  19:00    Male  Water tower  Chicago     No
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17    Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 990   Clothing     25         4    100    Cash       5
# 991  Furniture     96         7    672    Card       3
# ...

# %%
sales['Invoice ID']
# Out:
# 0      460489604
# 1      471006167
# 2      411909258
# 3      487313402
# 4      197763430
#          ...
# 995    818829599
# 996    556589713
# 997     82324424
# 998    783661702
# 999    759171975
# Name: Invoice ID, Length: 1000, dtype: int64

# %%
sales['Category']
# Out:
# 0      Groceries
# 1        Fashion
# 2       Clothing
# 3       Sporting
# 4          Books
#          ...
# 995    Groceries
# 996    Groceries
# 997     Clothing
# 998     Clothing
# 999     Clothing
# Name: Category, Length: 1000, dtype: object

# %%
sales['Category'].unique()
# Out:
# array(['Groceries', 'Fashion', 'Clothing', 'Sporting', 'Books',
#        'Furniture'], dtype=object)

# %%
sales.iloc[200]
# Out:
# Invoice ID      576523018
# Date            2/15/2018
# Time                12:35
# Gender               Male
# Location      Water tower
# City              Chicago
# Member                 No
# Category        Groceries
# Price                  82
# Quantity                1
# Total                  82
# Payment              Card
# Rating                  4
# Name: 200, dtype: object

# %%
sales[200:210]
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 200   576523018  2/15/2018  12:35    Male  Water tower  Chicago     No
# 201   414119922  1/30/2018  11:07    Male  Water tower  Chicago     No
# 202   123247697   2/8/2018  20:03    Male   Brookfield  NewYork     No
# 203    40419058  1/26/2018  14:53    Male  Water tower  Chicago    Yes
# 204   890497298  2/25/2018  18:06  Female  Water tower  Chicago     No
# 205   885702268  1/28/2018  12:45    Male   Brookfield  NewYork     No
# 206   172252194  3/22/2018  20:10  Female    Park lane   Dallas     No
# 207   866140211  2/25/2018  13:34  Female    Park lane   Dallas     No
# 208   597678548  3/15/2018  17:35    Male  Water tower  Chicago    Yes
# 209   428818456  2/25/2018  18:50    Male    Park lane   Dallas    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 200  Groceries     82         1     82    Card       4
# 201   Sporting     44         7    308    Card       3
# ...

# %% [markdown]
# # Part 2

# %%
sales[sales['Gender']=='Male']
# Out:
#      Invoice ID       Date   Time Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46   Male   Brookfield  NewYork    Yes
# 2     411909258  2/25/2018  13:33   Male  Water tower  Chicago     No
# 5     263634050   3/9/2018  17:55   Male   Brookfield  NewYork    Yes
# 6      99646662   3/4/2018  13:21   Male  Water tower  Chicago     No
# 7     188869875   3/8/2018  13:24   Male    Park lane   Dallas     No
# ..          ...        ...    ...    ...          ...      ...    ...
# 992   927909627   3/2/2018  13:35   Male   Brookfield  NewYork     No
# 994   446582560  1/31/2018  19:00   Male  Water tower  Chicago     No
# 995   818829599  3/26/2018  11:19   Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17   Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44   Male   Brookfield  NewYork     No
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %%
sales[sales['Gender']=='Male'].head(10)
# Out:
#     Invoice ID       Date   Time Gender     Location     City Member  \
# 0    460489604  1/25/2018  16:46   Male   Brookfield  NewYork    Yes
# 2    411909258  2/25/2018  13:33   Male  Water tower  Chicago     No
# 5    263634050   3/9/2018  17:55   Male   Brookfield  NewYork    Yes
# 6     99646662   3/4/2018  13:21   Male  Water tower  Chicago     No
# 7    188869875   3/8/2018  13:24   Male    Park lane   Dallas     No
# 8    325637547  1/18/2018  15:33   Male    Park lane   Dallas    Yes
# 11   846531724  3/15/2018  12:12   Male    Park lane   Dallas     No
# 12   149894432  1/12/2018  11:12   Male    Park lane   Dallas     No
# 17    90524319  3/19/2018  18:18   Male    Park lane   Dallas    Yes
# 19   729486362   3/7/2018  12:50   Male  Water tower  Chicago     No
#
#      Category  Price  Quantity  Total Payment  Rating
# 0   Groceries     30         1     30    Cash       2
# 2    Clothing     57         2    114    Cash       5
# ...

# %%
sales[sales['Total']>100]
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5     263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# ..          ...        ...    ...     ...          ...      ...    ...
# 994   446582560  1/31/2018  19:00    Male  Water tower  Chicago     No
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 1      Fashion     35         5    175    Card       3
# ...

# %%
sales['Payment'].unique()
# Out:
# array(['Cash', 'Card', 'Gpay'], dtype=object)

# %%
sales[sales['Payment']=='Cash']
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 6      99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# 7     188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 989   941364541  3/13/2018  14:53  Female   Brookfield  NewYork     No
# 990   752407865  1/15/2018  10:01    Male  Water tower  Chicago    Yes
# 993   455112063  3/19/2018  17:30  Female   Brookfield  NewYork    Yes
# 994   446582560  1/31/2018  19:00    Male  Water tower  Chicago     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %% [markdown]
# # Task 1

# %%
sales[sales['City']=='NewYork']
# Out:
#      Invoice ID       Date   Time  Gender    Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male  Brookfield  NewYork    Yes
# 5     263634050   3/9/2018  17:55    Male  Brookfield  NewYork    Yes
# 10    388412668  2/26/2018  11:32  Female  Brookfield  NewYork     No
# 14    547572603  3/21/2018  13:23  Female  Brookfield  NewYork     No
# 15    355981315  2/15/2018  15:47  Female  Brookfield  NewYork    Yes
# ..          ...        ...    ...     ...         ...      ...    ...
# 991   699906043  2/15/2018  12:58    Male  Brookfield  NewYork    Yes
# 992   927909627   3/2/2018  13:35    Male  Brookfield  NewYork     No
# 993   455112063  3/19/2018  17:30  Female  Brookfield  NewYork    Yes
# 997    82324424   2/6/2018  11:44    Male  Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female  Brookfield  NewYork     No
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %%
sales['Category'].unique()
# Out:
# array(['Groceries', 'Fashion', 'Clothing', 'Sporting', 'Books',
#        'Furniture'], dtype=object)

# %%
sales[sales['Price']>=100]
sales[sales['Price']<=200]
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17    Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %% [markdown]
# # part 3

# %%
# performing some arithmetic operations

# %%
sales.sum()['Total']
# Out:
# 207788

# %%
sales.sum()['Quantity']
# Out:
# 4059

# %%
sales.max()
# Out:
# Invoice ID      999665753
# Date             3/9/2018
# Time                20:59
# Gender               Male
# Location      Water tower
# City              NewYork
# Member                Yes
# Category         Sporting
# Price                 100
# Quantity                7
# Total                 693
# Payment              Gpay
# Rating                  5
# dtype: object

# %%
sales.max()['Total']
# Out:
# 693

# %%
sales[sales['Total']==sales.max()['Total']]
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 47    315624039  3/30/2018  19:45  Female  Water tower  Chicago    Yes
# 679   270918350  3/27/2018  13:21  Female    Park lane   Dallas    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 47   Groceries     99         7    693    Gpay       3
# 679  Groceries     99         7    693    Gpay       2

# %%
sales['Total'].min()
# Out:
# 1

# %%
sales.mean()['Total']
# Out:
# <ipython-input-26-9ee17d69bcaa>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sales.mean()['Total']
# 207.788

# %% [markdown]
# # Task 2

# %%
sales[sales['Total']==sales.min()['Total']]
# Out:
#      Invoice ID       Date   Time  Gender   Location    City Member  \
# 184   801334050  1/21/2018  20:18  Female  Park lane  Dallas     No
# 587   646176653  3/10/2018  19:39    Male  Park lane  Dallas    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 184  Furniture      1         1      1    Gpay       2
# 587   Sporting      1         1      1    Cash       2

# %% [markdown]
# # part 4

# %%
sales.groupby('City').sum()['Total']
# Out:
# <ipython-input-28-2964e2057de4>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales.groupby('City').sum()['Total']
# City
# Chicago    65215
# Dallas     70432
# NewYork    72141
# Name: Total, dtype: int64

# %%
sales.groupby('Date').sum()
# Out:
# <ipython-input-29-59d227e365dd>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales.groupby('Date').sum()
#            Invoice ID  Price  Quantity  Total  Rating
# Date
# 1/1/2018   5754968491    722        42   2649      45
# 1/10/2018  5071442922    433        27   1116      25
# 1/11/2018  4596704479    397        34   1562      20
# 1/12/2018  5999941284    603        44   2625      36
# 1/13/2018  6152497894    435        50   2340      26
# ...               ...    ...       ...    ...     ...
# 3/5/2018   7176403264   1001        76   4616      48
# 3/6/2018   4759166414    459        50   1915      35
# 3/7/2018   5519232431    237        42   1048      24
# 3/8/2018   5365615999    759        38   2638      33
# 3/9/2018   6478665906    882        72   4300      48
#
# ...

# %%
sales.groupby('Date').sum()['Total']
# Out:
# <ipython-input-30-be5152270f21>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales.groupby('Date').sum()['Total']
# Date
# 1/1/2018     2649
# 1/10/2018    1116
# 1/11/2018    1562
# 1/12/2018    2625
# 1/13/2018    2340
#              ...
# 3/5/2018     4616
# 3/6/2018     1915
# 3/7/2018     1048
# 3/8/2018     2638
# 3/9/2018     4300
# Name: Total, Length: 89, dtype: int64

# %% [markdown]
# # task 3

# %%
sales.groupby('Gender').sum()['Total']
# Out:
# <ipython-input-31-2c92b81ae3f3>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales.groupby('Gender').sum()['Total']
# Gender
# Female    106452
# Male      101336
# Name: Total, dtype: int64

# %%
sales.groupby('Gender')['Total'].sum()
# Out:
# Gender
# Female    106452
# Male      101336
# Name: Total, dtype: int64

# %%
sales.groupby('City').sum()['Total']
# Out:
# <ipython-input-33-2964e2057de4>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales.groupby('City').sum()['Total']
# City
# Chicago    65215
# Dallas     70432
# NewYork    72141
# Name: Total, dtype: int64

# %% [markdown]
# # Part 5

# %%
sales
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17    Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %%
# Q1) Which location has the highest and lowest sales?
sales.groupby('Location')

# %%
location_list=sales.groupby('Location')

# %%
location=[x for x,y in location_list]

# %%
location
# Out:
# ['Brookfield', 'Park lane', 'Water tower']

# %%
sales.groupby('Location').sum()['Total']
# Out:
# <ipython-input-39-d0d9922b1362>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales.groupby('Location').sum()['Total']
# Location
# Brookfield     72141
# Park lane      70432
# Water tower    65215
# Name: Total, dtype: int64

# %%
# Q2) Represent the sales on bar chart, also show the market share for each location using a pie chart?
import matplotlib.pyplot as plt

# %%
plt.bar(location,sales.groupby('Location').sum()['Total'])
# Out:
# <ipython-input-41-1b6d8e1e57ba>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   plt.bar(location,sales.groupby('Location').sum()['Total'])
# <BarContainer object of 3 artists>

# %%
plt.pie(sales.groupby('Location').sum()['Total'],labels=location,autopct='%1.1f%%')
# Out:
# <ipython-input-42-ad5cdf37dadd>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   plt.pie(sales.groupby('Location').sum()['Total'],labels=location,autopct='%1.1f%%')
# ([<matplotlib.patches.Wedge at 0x7fcfa0c71000>,
# ...
#  [Text(0.5080357843151303, 0.9756534435214743, 'Brookfield'),
#   Text(-1.0939745592878725, -0.11497679605427102, 'Park lane'),
#   Text(0.6072323961649049, -0.917207074246502, 'Water tower')],
#  [Text(0.27711042780825285, 0.5321746055571678, '34.7%'),
#   Text(-0.596713395975203, -0.06271461602960236, '33.9%'),
#   Text(0.3312176706354026, -0.5002947677708193, '31.4%')])

# %% [markdown]
# # Part 6

# %%
# Q1) which location has more female customers and which location has more male?
sales.groupby(['Location']).count()
# Out:
#              Invoice ID  Date  Time  Gender  City  Member  Category  Price  \
# Location
# Brookfield          340   340   340     340   340     340       340    340
# Park lane           332   332   332     332   332     332       332    332
# Water tower         328   328   328     328   328     328       328    328
#
#              Quantity  Total  Payment  Rating
# Location
# Brookfield        340    340      340     340
# Park lane         332    332      332     332
# Water tower       328    328      328     328

# %%
location_sales=sales.groupby(['Location','Gender']).count()['Invoice ID']

# %%
location_sales
# Out:
# Location     Gender
# Brookfield   Female    179
#              Male      161
# Park lane    Female    179
#              Male      153
# Water tower  Female    143
#              Male      185
# Name: Invoice ID, dtype: int64

# %%
location_sales.unstack(level=0)
# Out:
# Location  Brookfield  Park lane  Water tower
# Gender
# Female           179        179          143
# Male             161        153          185

# %%
unstacked_sales=location_sales.unstack(level=0)

# %%
unstacked_sales.plot(kind='bar')
# Out:
# <Axes: xlabel='Gender'>

# %%
location_sales=sales.groupby(['Gender','Location']).count()['Invoice ID']

# %%
location_sales.unstack(level=0).plot(kind='bar')
# Out:
# <Axes: xlabel='Location'>

# %% [markdown]
# # Part 7

# %%
# Q1) What days of the month makes most sales?

# %%
sales['Date']
# Out:
# 0      1/25/2018
# 1      3/19/2018
# 2      2/25/2018
# 3      1/22/2018
# 4      2/18/2018
#          ...
# 995    3/26/2018
# 996    2/20/2018
# 997     2/6/2018
# 998    1/29/2018
# 999    1/31/2018
# Name: Date, Length: 1000, dtype: object

# %%
pd.to_datetime(sales['Date']).dt.day
# Out:
# 0      25
# 1      19
# 2      25
# 3      22
# 4      18
#        ..
# 995    26
# 996    20
# 997     6
# 998    29
# 999    31
# Name: Date, Length: 1000, dtype: int64

# %%
sales['Day']=pd.to_datetime(sales['Date']).dt.day

# %%
sales.head(10)
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5   263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# 6    99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# 7   188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# 8   325637547  1/18/2018  15:33    Male    Park lane   Dallas    Yes
# 9   562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating  Day
# 0  Groceries     30         1     30    Cash       2   25
# 1    Fashion     35         5    175    Card       3   19
# ...

# %%
day_sales=sales.groupby('Day').sum()['Total']
# Out:
# <ipython-input-56-0ea696a5b594>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   day_sales=sales.groupby('Day').sum()['Total']

# %%
day_sales.plot()
# Out:
# <Axes: xlabel='Day'>

# %% [markdown]
# # Part 8

# %%
# Q1) which branch has more members vs which has less members?

# %%
sales.head(5)
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating  Day
# 0  Groceries     30         1     30    Cash       2   25
# 1    Fashion     35         5    175    Card       3   19
# 2   Clothing     57         2    114    Cash       5   25
# 3   Sporting     89         4    356    Gpay       1   22
# 4      Books     82         5    410    Cash       4   18

# %%
members=sales.groupby(['Member','Location']).count()['Invoice ID']

# %%
members.unstack(level=0)
# Out:
# Member        No  Yes
# Location
# Brookfield   173  167
# Park lane    167  165
# Water tower  159  169

# %%
members.unstack(level=0).plot(kind='bar')
# Out:
# <Axes: xlabel='Location'>

# %%
sales.groupby(['Location']).mean()['Rating']
# Out:
# <ipython-input-63-0d2213459d27>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales.groupby(['Location']).mean()['Rating']
# Location
# Brookfield     2.782353
# Park lane      3.021084
# Water tower    3.118902
# Name: Rating, dtype: float64

# %%
rating=sales.groupby(['Location']).mean()['Rating']
# Out:
# <ipython-input-64-c33a7695efbd>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   rating=sales.groupby(['Location']).mean()['Rating']

# %%
rating.plot(kind='bar')
# Out:
# <Axes: xlabel='Location'>

# %% [markdown]
# # Part 9

# %%
#Q1) Which city has more female shopping ?
female_shoppers=sales.groupby(['City','Gender']).count()['Invoice ID']

# %%
female_shoppers.unstack(level=0).plot(kind='bar')
# Out:
# <Axes: xlabel='Gender'>

# %%
#Q2) Who spends more, male or female ?
sales.groupby('Gender').sum()['Total']
# Out:
# <ipython-input-70-082339fc95f1>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales.groupby('Gender').sum()['Total']
# Gender
# Female    106452
# Male      101336
# Name: Total, dtype: int64

# %%
spend=sales.groupby('Gender').sum()['Total']
# Out:
# <ipython-input-71-36b1756fac01>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   spend=sales.groupby('Gender').sum()['Total']

# %%
spend.plot(kind='bar')
# Out:
# <Axes: xlabel='Gender'>

# %%
# Q3) Which type of customer spends more member or non member ?
sales.groupby('Member').sum()['Total']
# Out:
# <ipython-input-83-5bf5a76328fe>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales.groupby('Member').sum()['Total']
# Member
# No     100245
# Yes    107543
# Name: Total, dtype: int64

# %%
spend_cust=sales.groupby('Member').sum()['Total']
# Out:
# <ipython-input-85-68e6751c551b>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   spend_cust=sales.groupby('Member').sum()['Total']

# %%
spend_cust.plot(kind='bar')
# Out:
# <Axes: xlabel='Member'>

# %%
# Q4) Which product line sells more ?
sales.groupby('Category').sum()['Total']
# Out:
# <ipython-input-88-180c24fb79da>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales.groupby('Category').sum()['Total']
# Category
# Books        36103
# Clothing     35925
# Fashion      32778
# Furniture    34141
# Groceries    31236
# Sporting     37605
# Name: Total, dtype: int64

# %%
prod_line=sales.groupby('Category').sum()['Total']
# Out:
# <ipython-input-89-1eeba21bae35>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   prod_line=sales.groupby('Category').sum()['Total']

# %%
prod_line.plot(kind="bar")
# Out:
# <Axes: xlabel='Category'>

# %%
# Q5) Which product line is popular among men vs women ?
sales.groupby(['Category','Gender']).sum()['Total']
# Out:
# <ipython-input-101-51a79bf74b93>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales.groupby(['Category','Gender']).sum()['Total']
# Category   Gender
# Books      Female    18793
#            Male      17310
# Clothing   Female    17883
#            Male      18042
# Fashion    Female    17784
#            Male      14994
# Furniture  Female    15307
#            Male      18834
# Groceries  Female    17300
#            Male      13936
# Sporting   Female    19385
#            Male      18220
# Name: Total, dtype: int64

# %%
prodline_gender=sales.groupby(['Category','Gender']).sum()['Total']
# Out:
# <ipython-input-120-7b780656f354>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   prodline_gender=sales.groupby(['Category','Gender']).sum()['Total']

# %%
prodline_gender.unstack(level=0).plot(kind='bar')
# Out:
# <Axes: xlabel='Gender'>

# %% [markdown]
# # Part 10

# %%
# Q1) Which month have more sales ?

# %%
sales['Month']=pd.to_datetime(sales['Date']).dt.month

# %%
sales['Month']
# Out:
# 0      1
# 1      3
# 2      2
# 3      1
# 4      2
#       ..
# 995    3
# 996    2
# 997    2
# 998    1
# 999    1
# Name: Month, Length: 1000, dtype: int64

# %%
sales.groupby('Month').sum()['Total']
# Out:
# <ipython-input-79-499a05481ea0>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales.groupby('Month').sum()['Total']
# Month
# 1    71652
# 2    63850
# 3    72286
# Name: Total, dtype: int64

# %%
sales_by_month=sales.groupby('Month').sum()['Total']
# Out:
# <ipython-input-80-6be3d810b51f>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales_by_month=sales.groupby('Month').sum()['Total']

# %%
sales_by_month.plot(kind='bar')
# Out:
# <Axes: xlabel='Month'>
