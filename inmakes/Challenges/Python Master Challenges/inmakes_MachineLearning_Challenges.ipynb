# %% [markdown]
# # challenge 2

# %%
# do EDD of the Movie dataset and listdown your observations

# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
df=pd.read_csv('Movie_collection.csv')

# %%
df
# Out:
#      Collection  Marketing expense  Production expense  Multiplex coverage  \
# 0         48000            20.1264               59.62               0.462
# 1         43200            20.5462               69.14               0.531
# 2         69400            20.5458               69.14               0.531
# 3         66800            20.6474               59.36               0.542
# 4         72400            21.3810               59.36               0.542
# ..          ...                ...                 ...                 ...
# 501       44800            21.2526               78.86               0.427
# 502       41200            20.9054               78.86               0.427
# 503       47800            21.2152               78.86               0.427
# 504       44000            22.1918               78.86               0.427
# 505       38000            20.9482               78.86               0.427
#
# ...

# %%
df.shape
# Out:
# (506, 20)

# %%
df.describe()
# Out:
#           Collection  Marketing expense  Production expense  \
# count     506.000000         506.000000          506.000000
# mean    45057.707510          92.270471           77.273557
# std     18364.351764         172.030902           13.720706
# min     10000.000000          20.126400           55.920000
# 25%     34050.000000          21.640900           65.380000
# 50%     42400.000000          25.130200           74.380000
# 75%     50000.000000          93.541650           91.200000
# max    100000.000000        1799.524000          110.480000
#
#        Multiplex coverage        Budget  Movie_length  Lead_ Actor_Rating  \
# count          506.000000    506.000000    506.000000          506.000000
# mean             0.445305  34911.144022    142.074901            8.014002
# std              0.115878   3903.038232     28.148861            1.054266
# min              0.129000  19781.355000     76.400000            3.840000
# ...

# %%
sns.boxplot(y="Time_taken",data=df)
# Out:
# <Axes: ylabel='Time_taken'>

# %%
#OBSERVATION:
# missing values in Marketing expense
# Time_taken havie outliers
# movies with higher Lead_Actor_Rating tend to have higher Director_rating, and vice versa

# %% [markdown]
# # challenge 3

# %%
# identify and transform the varibles as required. Delete the variables which are identified as not required

# %%
np.percentile(df.Time_taken,[99][0])
# Out:
# nan

# %%
mvt=np.percentile(df.Time_taken,[99][0])

# %%
df.Budget[(df.Time_taken>3*mvt)]=3*mvt
# Out:
# <ipython-input-78-3f426f919019>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Budget[(df.Time_taken>3*mvt)]=3*mvt

# %%
df[(df.Time_taken>mvt)]
# Out:
# Empty DataFrame
# Columns: [Collection, Marketing expense, Production expense, Multiplex coverage, Budget, Movie_length, Lead_ Actor_Rating, Lead_Actress_rating, Director_rating, Producer_rating, Critic_rating, Trailer_views, 3D_available, Time_taken, Twitter_hastags, Genre, Avg_age_actors, MPAA_film_rating, Num_multiplex, Start_Tech_Oscar]
# Index: []

# %%
np.percentile(df.Collection,[1][0])
# Out:
# 14020.0

# %%
mvc=np.percentile(df.Collection,[1][0])

# %%
df[df.Collection<mvc]
# Out:
#      Collection  Marketing expense  Production expense  Multiplex coverage  \
# 398       10000           787.0360               91.20               0.307
# 399       12600           218.3310               91.20               0.307
# 400       11200           520.9220               91.20               0.307
# 405       10000          1378.4160               91.20               0.307
# 414       14000           934.9220               91.20               0.307
# 489       14000            23.6674              110.48               0.391
#
#         Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# 398  30291.415         173.5               9.215                9.370
# 399  32507.860         151.3               9.150                9.380
# 400  33257.785         173.5               9.135                9.310
# 405  31569.065         173.5               9.235                9.405
# 414  25103.045         173.5               9.130                9.250
# ...

# %%
df.Collection[(df.Collection<0.3*mvc)]=0.3*mvc
# Out:
# <ipython-input-83-1a840b583440>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Collection[(df.Collection<0.3*mvc)]=0.3*mvc

# %%
df.describe()
# Out:
#           Collection  Marketing expense  Production expense  \
# count     506.000000         506.000000          506.000000
# mean    45057.707510          92.270471           77.273557
# std     18364.351764         172.030902           13.720706
# min     10000.000000          20.126400           55.920000
# 25%     34050.000000          21.640900           65.380000
# 50%     42400.000000          25.130200           74.380000
# 75%     50000.000000          93.541650           91.200000
# max    100000.000000        1799.524000          110.480000
#
#        Multiplex coverage        Budget  Movie_length  Lead_ Actor_Rating  \
# count          506.000000    506.000000    506.000000          506.000000
# mean             0.445305  34911.144022    142.074901            8.014002
# std              0.115878   3903.038232     28.148861            1.054266
# min              0.129000  19781.355000     76.400000            3.840000
# ...

# %%
del df['Twitter_hastags']

# %%
df.describe()
# Out:
#           Collection  Marketing expense  Production expense  \
# count     506.000000         506.000000          506.000000
# mean    45057.707510          92.270471           77.273557
# std     18364.351764         172.030902           13.720706
# min     10000.000000          20.126400           55.920000
# 25%     34050.000000          21.640900           65.380000
# 50%     42400.000000          25.130200           74.380000
# 75%     50000.000000          93.541650           91.200000
# max    100000.000000        1799.524000          110.480000
#
#        Multiplex coverage        Budget  Movie_length  Lead_ Actor_Rating  \
# count          506.000000    506.000000    506.000000          506.000000
# mean             0.445305  34911.144022    142.074901            8.014002
# std              0.115878   3903.038232     28.148861            1.054266
# min              0.129000  19781.355000     76.400000            3.840000
# ...

# %% [markdown]
# # Challenge 4

# %%
# impute the missing values in the movie dataset. Use a value of your choice (mean/median) to replace the missing values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Collection           506 non-null    int64
#  1   Marketing expense    506 non-null    float64
#  2   Production expense   506 non-null    float64
#  3   Multiplex coverage   506 non-null    float64
#  4   Budget               506 non-null    float64
#  5   Movie_length         506 non-null    float64
#  6   Lead_ Actor_Rating   506 non-null    float64
#  7   Lead_Actress_rating  506 non-null    float64
#  8   Director_rating      506 non-null    float64
#  9   Producer_rating      506 non-null    float64
#  10  Critic_rating        506 non-null    float64
#  11  Trailer_views        506 non-null    int64
#  12  3D_available         506 non-null    object
#  13  Time_taken           494 non-null    float64
#  14  Genre                506 non-null    object
# ...

# %%
df.Time_taken=df.Time_taken.fillna(df.Time_taken.mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Collection           506 non-null    int64
#  1   Marketing expense    506 non-null    float64
#  2   Production expense   506 non-null    float64
#  3   Multiplex coverage   506 non-null    float64
#  4   Budget               506 non-null    float64
#  5   Movie_length         506 non-null    float64
#  6   Lead_ Actor_Rating   506 non-null    float64
#  7   Lead_Actress_rating  506 non-null    float64
#  8   Director_rating      506 non-null    float64
#  9   Producer_rating      506 non-null    float64
#  10  Critic_rating        506 non-null    float64
#  11  Trailer_views        506 non-null    int64
#  12  3D_available         506 non-null    object
#  13  Time_taken           506 non-null    float64
#  14  Genre                506 non-null    object
# ...

# %%
df.describe()
# Out:
#           Collection  Marketing expense  Production expense  \
# count     506.000000         506.000000          506.000000
# mean    45057.707510          92.270471           77.273557
# std     18364.351764         172.030902           13.720706
# min     10000.000000          20.126400           55.920000
# 25%     34050.000000          21.640900           65.380000
# 50%     42400.000000          25.130200           74.380000
# 75%     50000.000000          93.541650           91.200000
# max    100000.000000        1799.524000          110.480000
#
#        Multiplex coverage        Budget  Movie_length  Lead_ Actor_Rating  \
# count          506.000000    506.000000    506.000000          506.000000
# mean             0.445305  34911.144022    142.074901            8.014002
# std              0.115878   3903.038232     28.148861            1.054266
# min              0.129000  19781.355000     76.400000            3.840000
# ...

# %% [markdown]
# # challenge 5

# %%
# treat the outliers in the movie dataset. Use upper and lower boundaries of your choice to limit the outlying values.

# %% [markdown]
# # challenge 6

# %%
# create a dummy variables for all the categorical variables presnet in the movie database

# %%
df
# Out:
#      Collection  Marketing expense  Production expense  Multiplex coverage  \
# 0         48000            20.1264               59.62               0.462
# 1         43200            20.5462               69.14               0.531
# 2         69400            20.5458               69.14               0.531
# 3         66800            20.6474               59.36               0.542
# 4         72400            21.3810               59.36               0.542
# ..          ...                ...                 ...                 ...
# 501       44800            21.2526               78.86               0.427
# 502       41200            20.9054               78.86               0.427
# 503       47800            21.2152               78.86               0.427
# 504       44000            22.1918               78.86               0.427
# 505       38000            20.9482               78.86               0.427
#
# ...

# %%
df=pd.get_dummies(df)

# %%
df
# Out:
#      Collection  Marketing expense  Production expense  Multiplex coverage  \
# 0         48000            20.1264               59.62               0.462
# 1         43200            20.5462               69.14               0.531
# 2         69400            20.5458               69.14               0.531
# 3         66800            20.6474               59.36               0.542
# 4         72400            21.3810               59.36               0.542
# ..          ...                ...                 ...                 ...
# 501       44800            21.2526               78.86               0.427
# 502       41200            20.9054               78.86               0.427
# 503       47800            21.2152               78.86               0.427
# 504       44000            22.1918               78.86               0.427
# 505       38000            20.9482               78.86               0.427
#
# ...

# %%
df.head()
# Out:
#    Collection  Marketing expense  Production expense  Multiplex coverage  \
# 0       48000            20.1264               59.62               0.462
# 1       43200            20.5462               69.14               0.531
# 2       69400            20.5458               69.14               0.531
# 3       66800            20.6474               59.36               0.542
# 4       72400            21.3810               59.36               0.542
#
#       Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# 0  36524.125         138.7               7.825                8.095
# 1  35668.655         152.4               7.505                7.650
# 2  39912.675         134.6               7.485                7.570
# 3  38873.890         119.3               6.895                7.035
# 4  39701.585         127.7               6.920                7.070
#
#    Director_rating  Producer_rating  ...  Avg_age_actors  Num_multiplex  \
# ...

# %% [markdown]
# # challenge 7

# %%
# find the relationship btw "Budget" of the movie and whether the movie will win a "Start-tech-oscar" or not

# %% [markdown]
# # challenge 8

# %%
# this time, use all the variables to predict whether the movie will win a "Start-tech-oscar" or not

# %% [markdown]
# # challenge 9

# %%
# train the LDA model and create the configuration matrix. Compare the confusion matrix from LDA with confusion matrix from the Logistic Regression model.

# %% [markdown]
# # challenge 10

# %%
# split the data into test and train in the ratio 20:80. Use the training data to train logistic and LDA model. Use the test data to create confusion matrix and compare their perfomance

# %% [markdown]
# # challenge 11

# %%
# use the same test and train data to run the KNN model. Use different values in K and draw the confusion matrix to decide the best K value for the model.
