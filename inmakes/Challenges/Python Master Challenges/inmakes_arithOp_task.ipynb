# %% [markdown]
# # Create 2 series set & 2 frameset.Then add them and minise

# %%
from pandas import Series
series1=Series([1,2,3,4,5])
series2=Series([100,200,300,],index=['speed','temp','humidity'])

# %%
series1+series2
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# humidity   NaN
# speed      NaN
# temp       NaN
# dtype: float64

# %%
from pandas import DataFrame
data1={'speed':[100,200,300],
      'temp':[12,56,45]}
data1
# Out:
# {'speed': [100, 200, 300], 'temp': [12, 56, 45]}

# %%
frame1=DataFrame(data1)

# %%
frame1
# Out:
#    speed  temp
# 0    100    12
# 1    200    56
# 2    300    45

# %%
data2={'speed':[100,200,300],
      'temp':[12,56,45],
      'humidity':[78,90,67]}
data2
# Out:
# {'speed': [100, 200, 300], 'temp': [12, 56, 45], 'humidity': [78, 90, 67]}

# %%
frame2=DataFrame(data2)

# %%
frame2
# Out:
#    speed  temp  humidity
# 0    100    12        78
# 1    200    56        90
# 2    300    45        67

# %%
frame1+frame2
# Out:
#    humidity  speed  temp
# 0       NaN    200    24
# 1       NaN    400   112
# 2       NaN    600    90

# %%
frame2-series2
# Out:
#    speed  temp  humidity
# 0      0  -188      -222
# 1    100  -144      -210
# 2    200  -155      -233

# %%
ser=Series([3,7,1,4,7,2],index=[2,7,3,5,8,4])

# %%
ser
# Out:
# 2    3
# 7    7
# 3    1
# 5    4
# 8    7
# 4    2
# dtype: int64

# %%
ser.sort_index()
# Out:
# 2    3
# 3    1
# 4    2
# 5    4
# 7    7
# 8    7
# dtype: int64

# %% [markdown]
# # Arithmetic Operation Task

# %%
from pandas import Series
car1=Series([1,2,3])
car2=Series([6,7,8],index=['speed','torq','bhp'])

# %%
car1+car2
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# bhp     NaN
# speed   NaN
# torq    NaN
# dtype: float64

# %%
from pandas import DataFrame
data1={'speed':[100,200,300],
       'torq':[300,310,320]}
data1
# Out:
# {'speed': [100, 200, 300], 'torq': [300, 310, 320]}

# %%
perf1=DataFrame(data1)

# %%
perf1
# Out:
#    speed  torq
# 0    100   300
# 1    200   310
# 2    300   320

# %%
data2={'speed':[400,500,600],
       'torq':[400,410,420],
       'bhp':[130,140,150]}
data2
# Out:
# {'speed': [400, 500, 600], 'torq': [400, 410, 420], 'bhp': [130, 140, 150]}

# %%
perf2=DataFrame(data2)

# %%
perf1
# Out:
#    speed  torq
# 0    100   300
# 1    200   310
# 2    300   320

# %% [markdown]
# perf1+perf2

# %%
perf2-car2
# Out:
#    speed  torq  bhp
# 0    394   393  122
# 1    494   403  132
# 2    594   413  142
